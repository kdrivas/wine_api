# %%
# !pip install mlflow
# !pip install --upgrade pandas
# !pip install ray
# !pip install dataclasses
# !pip install bayesian-optimization
# !pip install hyperopt
# !pip install awswrangler
# !pip install --upgrade fsspec
# Out:
# ...
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# ...

# %%
import pandas as pd
import datetime
import awswrangler as wr

# %%
train_data = pd.read_csv('s3://rimac-analytics-temporal/individuals/Dante/mlflow_testing/data/input/raw/winequalityN.csv')

# %%
train_data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
train_data = train_data.fillna(-1)
prec_data = train_data.drop(['type'], axis=1)

# %%
wr.s3.to_csv(prec_data, 's3://rimac-analytics-temporal/individuals/Dante/mlflow_testing/data/input/prepro/wine.csv', index=False)
# Out:
# {'paths': ['s3://rimac-analytics-temporal/individuals/Dante/mlflow_testing/data/input/prepro/wine.csv'],
#  'partitions_values': {}}
